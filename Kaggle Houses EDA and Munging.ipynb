# %% [markdown]
# ### Kaggle House Price Prediction Competition
#
# This dataset has 79 feature columns so a large part of the work will be in feature selection and engineering.
#
# The evaluation metric is rmse

# %%
import pandas as pd
pd.set_option('display.max_columns', 100)
import numpy as np
import re
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')
import seaborn as sns
import mlxtend.plotting as mlxp
import warnings
warnings.filterwarnings('ignore')

from scipy.stats import kstest, levene, boxcox, mode

# %%
#Import data and take a copy for experimenting during exploration

test = pd.read_csv('test.csv')
test_id = test['Id'] # save id column for indexing final submission
house_test = test.copy()
house_test.drop(['Id'],inplace=True,axis=1)

train = pd.read_csv('train.csv')
train_id = train['Id']
house_train = train.copy()
house_train.drop(['Id'],inplace=True,axis=1)

# %%
# display(house_train.info()) #the number of features make this unwieldy =>

#split feature columns by data type to inspect further
type_dict = {str(k): list(v) for k, v in house_train.groupby(house_train.dtypes, axis=1)}

# display(house_train.loc[:,type_dict['int64']].info())
# display(house_train.loc[:,type_dict['int64']].head())

# display(house_train.loc[:,type_dict['float64']].info())
# display(house_train.loc[:,type_dict['float64']].head())

# display(house_train.loc[:,type_dict['object']].info())
# display(house_train.loc[:,type_dict['object']].head())

# %%
#Inspect numerical columns to get a feel for the shape of the data
# house_train.describe().T

# %%
# house_test.describe().T
# house_test.info()

# %%
display('Features containing NaNs in test set = {}'.format(house_test.isna().any().sum()))
display('Features containing NaNs in training set = {}'.format(house_train.isna().any().sum()))

na_col_train = house_train.isna().any()
train_na = house_train.loc[:,na_col_train].isna().sum()

na_col_test = house_test.isna().any()
test_na = house_test.loc[:,na_col_test].isna().sum()

pd.DataFrame([train_na,test_na],index=['train','test']).T
# Out:
# 'Features containing NaNs in test set = 33'
# 'Features containing NaNs in training set = 19'
#                train    test
# LotFrontage    259.0   227.0
# Alley         1369.0  1352.0
# MasVnrType       8.0    16.0
# MasVnrArea       8.0    15.0
# BsmtQual        37.0    44.0
# BsmtCond        37.0    45.0
# BsmtExposure    38.0    44.0
# BsmtFinType1    37.0    42.0
# BsmtFinType2    38.0    42.0
# Electrical       1.0     NaN
# FireplaceQu    690.0   730.0
# GarageType      81.0    76.0
# GarageYrBlt     81.0    78.0
# GarageFinish    81.0    78.0
# GarageQual      81.0    78.0
# GarageCond      81.0    78.0
# PoolQC        1453.0  1456.0
# Fence         1179.0  1169.0
# MiscFeature   1406.0  1408.0
# MSZoning         NaN     4.0
# Utilities        NaN     2.0
# Exterior1st      NaN     1.0
# Exterior2nd      NaN     1.0
# BsmtFinSF1       NaN     1.0
# BsmtFinSF2       NaN     1.0
# BsmtUnfSF        NaN     1.0
# TotalBsmtSF      NaN     1.0
# BsmtFullBath     NaN     2.0
# BsmtHalfBath     NaN     2.0
# KitchenQual      NaN     1.0
# Functional       NaN     2.0
# GarageCars       NaN     1.0
# GarageArea       NaN     1.0
# SaleType         NaN     1.0

# %% [markdown]
# 18 features in the training set contain NaNs, 33 features in the test set contain NaNs
#
# Looking at these is more detail:
#
# LotFrontage - all dwellings are houses so should have some frontage. I will impute this with the mean frontage for the Neighbourhood of the house
#
# Alley - defined in data description as meaning there is no alley access - change to "None"
#
# MasVrnType + MasVrnArea have multiple instances where the Area is 0 in which case that NaN should be set to None. There is one instance in the test set where an Area is given but no type. This is for record 1150. Inspecting this record the house is made of plywood and the most common Veneer type for Plywood houses when they have one is "BrkFace"
#
# Electrical - The house missing this info (training id 1379) has air con which implies it must have electrical. I will impute this as the modal electrical type
#
# MSZoning - all hosues must be zoned, impute as modal zone type
#
# Utilities - impute modal type
#
# Exterior1st - all houses have some kind of fininsh => impute modally based on MSSubClass
#
# KitchenQual - impute based on MSSubClass
#
# Functional - the descriptor says to assume typical unless information to the contrary so I will impute as typical
#
# SaleType - impute modally
#
# GarageCars and GarageArea - these both belong to test record 1116 which is listed as having a detached garage. If this was a training observation I may have dropped it but as it is a test record I cannot. One option is to assume that the garage being present was entered incorrectly, however the majority of houses in that zone type (RM) do have garages so I will impute using the modal values for houses in the same zone with a detached garage.
#
# The test set also has a GarageYrBlt listed as 2207. This is clearly a mistake and needs to be corrected.
#
# All other NaNs looks likely to be intentionally null values
#
# For imputing values I will use the training set to calculate values even if they are to be imputed into the test set as the training is normally larger making this good practice.

# %%
#Investigate missing Utilities observations
# house_train['Utilities'].value_counts()
#Almost all houses have 'AllPub' utilities => fillna with this

# %%
#Investigate missing BsmtQual values
# display(house_test[(house_test['BsmtQual'].isna()) & (house_test['TotalBsmtSF']>0)])
# house_train.loc[house_train['Neighborhood']=='IDOTRR'].groupby(['MSZoning','BsmtQual'])\
# .agg({'BsmtQual':'count','MSZoning':'count'})

#There are two values in the test set where there is a non-zero TotalBsmtSF area recorded but NA BsmtQual. Both houses
#come from the same Neighbourhood and Zoning. Looking at the training set houses with these characteristics have TA BsmtQual
#so I will impute as this.
#All Bsmt qualitative values where BsmtArea = 0 can be set to None

# house_train.loc[house_train['TotalBsmtSF']==0,['BsmtQual','BsmtCond','BsmtExposure','BsmtFinType1','BsmtFinType2']] = \
# house_train.loc[house_train['TotalBsmtSF']==0,['BsmtQual','BsmtCond','BsmtExposure','BsmtFinType1','BsmtFinType2']].fillna('hello')
# display(house_train.loc[house_train['TotalBsmtSF']==0,['BsmtQual','BsmtCond','BsmtExposure','BsmtFinType1','BsmtFinType2']])

# %%
#Investigating extra MasVnr NaN in test set

# display(house_train.loc[house_train['MasVnrType'].isna(),['MasVnrArea','MasVnrType']])

#There is a single entry in the test data set which has a veneer area but not a veneer type. This can be filled using the most
#common type for the Neighbourhood, all other missing values can be set to NaN

ind = house_test.index[(house_test['MasVnrArea']>0) & house_test['MasVnrType'].isna()]
neighborhood = house_test.loc[ind,'Neighborhood'].values
area_veneer = house_test.loc[house_train['Neighborhood']=='Mitchel']
display(neighborhood,area_veneer)
# Out:
# array(['Mitchel'], dtype=object)
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 5             60       RL         75.0    10000   Pave   NaN      IR1
# 46            60       RL         80.0    10791   Pave   NaN      Reg
# 71            30       RM         56.0     4485   Pave  Grvl      Reg
# 81            50       RM         53.0     5830   Pave   NaN      Reg
# 137           80       RL         85.0    19645   Pave   NaN      IR1
# 186           20       RL         85.0    11050   Pave   NaN      IR1
# 201           60       RL         95.0    12350   Pave   NaN      Reg
# 274           20       RL          NaN     7791   Pave   NaN      IR1
# 276           20       RL          NaN    15676   Pave   NaN      IR1
# 295           20       RL         60.0     7436   Pave   NaN      Reg
# 360           50       RM         60.0     5400   Pave   NaN      Reg
# 391           20       RL         62.0     7440   Pave   NaN      Reg
# 420           20       RL         90.0    11664   Pave   NaN      Reg
# 422           60       RL         70.0     8749   Pave   NaN      Reg
# 454          120       RM         44.0     3843   Pave   NaN      IR1
# 483           60       RL        101.0    13543   Pave   NaN      IR1
# 513           60       RL         85.0    10574   Pave   NaN      IR1
# 547           20       FV         62.0     7500   Pave  Pave      Reg
# 561           20       RL         95.0    19508   Pave   NaN      Reg
# 592           20       RL          NaN    11332   Pave   NaN      IR1
# 613           20       RL         76.0    11355   Pave   NaN      IR1
# 767           20       RL         74.0    11563   Pave   NaN      IR1
# 775           20       RL         79.0    11449   Pave   NaN      IR1
# 779          120       RM         32.0     4500   Pave   NaN      Reg
# 783          180       RM         21.0     1974   Pave   NaN      Reg
# 791           20       RL         85.0    10667   Pave   NaN      Reg
# 817           20       RL         63.0     9457   Pave   NaN      Reg
# 876           20       RL         75.0     9910   Pave   NaN      Reg
# 908          120       FV         30.0     5330   Pave  Pave      IR2
# 940           20       RL         50.0     5175   Pave   NaN      Reg
# 943           85       RL          NaN    10050   Pave   NaN      IR1
# 953           20       RL         60.0    11556   Pave   NaN      Reg
# 984           50       RM         50.0     5925   Pave   NaN      Reg
# 1008          50       RM         40.0     5680   Pave  Grvl      Reg
# 1048          20       RL         75.0    11750   Pave   NaN      IR1
# 1131          20       RL         67.0     8368   Pave   NaN      IR1
# 1138          20       RL         85.0    12633   Pave   NaN      IR1
# 1170          60       RL         82.0    16052   Pave   NaN      IR1
# 1176          85       RL          NaN     9927   Pave   NaN      IR1
# 1190         160       RL         24.0     2179   Pave   NaN      Reg
# 1193          20       RL        108.0    12228   Pave   NaN      Reg
# 1247          20       RL          NaN    13052   Pave   NaN      IR1
# 1252         120       FV         34.0     3628   Pave  Pave      Reg
# 1283          20       RL         72.0    10152   Pave   NaN      Reg
# 1327          30       RM         48.0     5747   Pave   NaN      Reg
# 1407          50       RL         72.0     7822   Pave   NaN      Reg
# 1434         120       RM         41.0     5748   Pave   NaN      IR1
# 1446         160       RM         41.0     2665   Pave   NaN      Reg
# 1453         160       RM         21.0     1526   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 5            Lvl    AllPub    Corner       Gtl      Gilbert       Norm
# 46           Lvl    AllPub    Inside       Gtl       NWAmes       Norm
# 71           Lvl    AllPub    Inside       Gtl      OldTown     Artery
# 81           Lvl    AllPub    Corner       Gtl      BrkSide      Feedr
# 137          Lvl    AllPub       FR2       Gtl      Crawfor       Norm
# 186          Lvl    AllPub    Corner       Gtl       NWAmes       Norm
# 201          Lvl    AllPub    Inside       Gtl      NridgHt       Norm
# 274          Lvl    AllPub    Inside       Gtl       Sawyer       RRAe
# 276          Low    AllPub    Inside       Gtl      Veenker       Norm
# 295          Lvl    AllPub    Inside       Gtl        NAmes       Norm
# 360          Lvl    AllPub    Inside       Gtl      OldTown       Norm
# 391          Lvl    AllPub    Inside       Gtl      Edwards       Norm
# 420          Lvl    AllPub    Corner       Gtl      CollgCr       Norm
# 422          Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 454          HLS    AllPub    Inside       Mod      Crawfor       Norm
# 483          HLS    AllPub    Corner       Gtl      StoneBr       Norm
# 513          Lvl    AllPub    Inside       Gtl      NridgHt       Norm
# 547          Lvl    AllPub    Inside       Gtl      Somerst       Norm
# 561          Lvl    AllPub    Inside       Gtl      Veenker       Norm
# 592          Lvl    AllPub    Corner       Gtl        NAmes       Norm
# 613          Lvl    AllPub    Corner       Gtl        NAmes       Norm
# 767          HLS    AllPub    Inside       Gtl       Timber       Norm
# 775          HLS    AllPub    Inside       Gtl       Timber       Norm
# 779          Lvl    AllPub       FR2       Gtl      Mitchel       Norm
# 783          Lvl    AllPub    Inside       Gtl      MeadowV       Norm
# 791          Lvl    AllPub    Inside       Gtl        NAmes       Norm
# 817          Lvl    AllPub    Inside       Gtl        NAmes       Norm
# 876          Lvl    AllPub    Inside       Gtl      Somerst      Feedr
# 908          Lvl    AllPub    Inside       Gtl      Somerst       Norm
# 940          Lvl    AllPub    Inside       Gtl      BrkSide       RRAn
# 943          Lvl    AllPub    Inside       Gtl        NAmes       Norm
# 953          Lvl    AllPub    Inside       Gtl        NAmes       Norm
# 984          Lvl    AllPub    Inside       Gtl      OldTown       Norm
# 1008         Lvl    AllPub    Inside       Gtl      OldTown       Norm
# 1048         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1131         HLS    AllPub    Inside       Gtl       Timber       Norm
# 1138         HLS    AllPub    Inside       Gtl       Timber       PosA
# 1170         Lvl    AllPub   CulDSac       Gtl      StoneBr       Norm
# 1176         Lvl    AllPub    Inside       Gtl       NWAmes       Norm
# 1190         Lvl    AllPub    Inside       Gtl      NPkVill       Norm
# 1193         Lvl    AllPub    Corner       Gtl      NridgHt       Norm
# 1247         Lvl    AllPub   CulDSac       Gtl       Sawyer       Norm
# 1252         Lvl    AllPub    Inside       Gtl      Somerst       Norm
# 1283         Lvl    AllPub    Inside       Gtl        NAmes       Norm
# 1327         Lvl    AllPub    Inside       Gtl      OldTown       Norm
# 1407         Bnk    AllPub    Corner       Gtl      Edwards     Artery
# 1434         HLS    AllPub    Inside       Mod      Crawfor       Norm
# 1446         Lvl    AllPub    Inside       Gtl      MeadowV       Norm
# 1453         Lvl    AllPub    Inside       Gtl      MeadowV       Norm
#
#      Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 5          Norm     1Fam     2Story            6            5       1993
# 46         Norm     1Fam     2Story            6            5       1993
# 71         Norm     1Fam     1Story            5            7       1920
# 81        Feedr     1Fam     1.5Fin            5            6       1950
# 137        Norm     1Fam       SLvl            7            6       1994
# 186        Norm     1Fam     1Story            7            5       1975
# 201        Norm     1Fam     2Story            9            5       2009
# 274        Norm     1Fam     1Story            5            8       1963
# 276        Norm     1Fam     1Story            8            8       1980
# 295        Norm     1Fam     1Story            4            7       1960
# 360        Norm     1Fam     1.5Fin            6            6       1920
# 391        Norm     1Fam     1Story            5            6       1954
# 420        Norm     1Fam     1Story            7            5       2002
# 422        Norm     1Fam     2Story            7            5       2002
# 454        Norm   TwnhsE     1Story            8            5       2007
# 483        Norm     1Fam     2Story            8            5       2005
# 513        Norm     1Fam     2Story            8            5       2004
# 547        Norm     1Fam     1Story            7            5       2007
# 561        Norm     1Fam     1Story            6            5       1974
# 592        Norm     1Fam     1Story            5            7       1960
# 613        Norm     1Fam     1Story            7            7       1958
# 767        Norm     1Fam     1Story            8            5       2006
# 775        Norm     1Fam     1Story            8            5       2007
# 779        Norm   TwnhsE     1Story            6            5       1997
# 783        Norm    Twnhs     SFoyer            4            7       1973
# 791        Norm     1Fam     1Story            6            6       1971
# 817        Norm     1Fam     1Story            5            6       1970
# 876        Norm     1Fam     1Story            7            6       2007
# 908        Norm   TwnhsE     1Story            8            5       2006
# 940       Feedr     1Fam     1Story            5            8       1958
# 943        Norm     1Fam     SFoyer            5            6       1966
# 953        Norm     1Fam     1Story            5            9       1953
# 984        Norm     1Fam     1.5Fin            4            6       1900
# 1008       Norm     1Fam     1.5Fin            5            3       1901
# 1048       Norm     1Fam     1Story            7            5       2005
# 1131       Norm     1Fam     1Story            7            5       2006
# 1138       PosA     1Fam     1Story           10            5       2006
# 1170       Norm     1Fam     2Story           10            5       2006
# 1176       Norm     1Fam     SFoyer            7            5       1976
# 1190       Norm    Twnhs     2Story            6            5       1976
# 1193       Norm     1Fam     1Story            7            5       2006
# 1247       Norm     1Fam     1Story            5            6       1965
# 1252       Norm   TwnhsE     1Story            7            5       2004
# 1283       Norm     1Fam     1Story            6            6       1956
# 1327       Norm     1Fam     1Story            3            4       1920
# 1407       Norm     1Fam     1.5Fin            6            3       1915
# 1434       Norm   TwnhsE     1Story            8            5       2005
# 1446       Norm   TwnhsE     2Story            5            6       1977
# 1453       Norm    Twnhs     2Story            4            5       1970
#
#       YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 5             1994     Gable  CompShg     HdBoard     HdBoard       None
# 46            1993     Gable  CompShg     MetalSd     MetalSd       None
# 71            1950     Gable  CompShg     Wd Sdng     Wd Sdng       None
# 81            1997     Gable  CompShg     MetalSd     MetalSd       None
# 137           2007     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 186           1975     Gable  CompShg     Plywood     Plywood       None
# 201           2009     Gable  CompShg     VinylSd     VinylSd       None
# 274           1995     Gable  CompShg     Plywood     Plywood       None
# 276           1980     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 295           1960     Gable  CompShg     VinylSd     VinylSd       None
# 360           1950     Gable  CompShg     MetalSd     MetalSd       None
# 391           1954     Gable  CompShg     Wd Sdng     Wd Sdng       None
# 420           2002       Hip  CompShg     VinylSd     VinylSd       None
# 422           2002     Gable  CompShg     VinylSd     VinylSd        NaN
# 454           2008       Hip  CompShg     CemntBd     CmentBd      Stone
# 483           2005     Gable  CompShg     VinylSd     VinylSd      Stone
# 513           2004     Gable  CompShg     VinylSd     VinylSd      Stone
# 547           2008     Gable  CompShg     CemntBd     CmentBd      Stone
# 561           1974     Gable  CompShg     HdBoard     ImStucc    BrkFace
# 592           2000     Gable  CompShg     Wd Sdng     Wd Sdng       None
# 613           2001     Gable  Tar&Grv     HdBoard     HdBoard    BrkFace
# 767           2007       Hip  CompShg     VinylSd     VinylSd      Stone
# 775           2007     Gable  CompShg     VinylSd     VinylSd       None
# 779           1997       Hip  CompShg     VinylSd     VinylSd    BrkFace
# 783           2006     Gable  CompShg     CemntBd     CmentBd       None
# 791           1971     Gable  CompShg     MetalSd     MetalSd    BrkFace
# 817           1990     Gable  CompShg     MetalSd     MetalSd       None
# 876           2007     Gable  CompShg     VinylSd     VinylSd       None
# 908           2007     Gable  CompShg     VinylSd     VinylSd        NaN
# 940           2000     Gable  CompShg     VinylSd     VinylSd       None
# 943           1966     Gable  CompShg     HdBoard     HdBoard    BrkFace
# 953           2006     Gable  CompShg     VinylSd     MetalSd       None
# 984           1950     Gable  CompShg     MetalSd     MetalSd       None
# 1008          1950     Gable  CompShg     AsbShng     AsbShng       None
# 1048          2006     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 1131          2007     Gable  CompShg     VinylSd     VinylSd       None
# 1138          2007       Hip  CompShg     MetalSd     MetalSd    BrkFace
# 1170          2006       Hip  CompShg     VinylSd     VinylSd      Stone
# 1176          1976     Gable  CompShg     VinylSd     Wd Shng      Stone
# 1190          1976     Gable  CompShg     Plywood     Brk Cmn       None
# 1193          2006       Hip  CompShg     VinylSd     VinylSd      Stone
# 1247          1965     Gable  CompShg     HdBoard     HdBoard       None
# 1252          2004     Gable  CompShg     MetalSd     MetalSd       None
# 1283          1994     Gable  CompShg     Wd Sdng     Wd Sdng       None
# 1327          1950     Gable  CompShg     Wd Sdng     Wd Sdng       None
# 1407          1950     Gable  CompShg     AsbShng     AsbShng       None
# 1434          2006       Hip  CompShg     CemntBd     CmentBd      Stone
# 1446          1977     Gable  CompShg     CemntBd     CmentBd       None
# 1453          1970     Gable  CompShg     CemntBd     CmentBd       None
#
#       MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond  \
# 5            0.0        TA        TA      PConc       Gd       TA
# 46           0.0        TA        TA      PConc       Gd       TA
# 71           0.0        TA        TA      PConc       TA       TA
# 81           0.0        TA        Gd     CBlock       TA       TA
# 137         44.0        TA        TA      PConc       Gd       TA
# 186          0.0        TA        TA     CBlock       TA       TA
# 201          0.0        Gd        TA      PConc       Ex       TA
# 274          0.0        Gd        Gd     CBlock       TA       TA
# 276        115.0        Gd        Gd     CBlock       Gd       Gd
# 295          0.0        TA        TA     CBlock       TA       TA
# 360          0.0        Fa        TA     BrkTil       TA       TA
# 391          0.0        TA        TA     CBlock       Gd       TA
# 420          0.0        Gd        TA      PConc       Gd       TA
# 422          NaN        Gd        TA      PConc       Gd       TA
# 454        174.0        Ex        TA      PConc       Ex       TA
# 483        130.0        Gd        TA      PConc       Ex       TA
# 513        126.0        Gd        TA      PConc       Ex       TA
# 547        210.0        Gd        TA      PConc       Gd       TA
# 561        144.0        TA        TA     CBlock       TA       TA
# 592          0.0        TA        TA     CBlock       TA       TA
# 613        125.0        TA        TA     CBlock       TA       TA
# 767        258.0        Gd        TA      PConc       Ex       TA
# 775          0.0        Gd        TA      PConc       Gd       TA
# 779        197.0        TA        TA      PConc       Ex       TA
# 783          0.0        TA        Gd     CBlock       Gd       TA
# 791        302.0        TA        TA     CBlock       TA       TA
# 817          0.0        TA        TA     CBlock       TA       TA
# 876          0.0        Gd        TA      PConc       Gd       TA
# 908          NaN        Gd        TA      PConc       Gd       TA
# 940          0.0        TA        TA     CBlock       TA       TA
# 943         87.0        TA        TA     CBlock       TA       TA
# 953          0.0        TA        Ex     CBlock       TA       TA
# 984          0.0        TA        TA     BrkTil       Fa       TA
# 1008         0.0        TA        TA     CBlock       TA       TA
# 1048       204.0        Gd        TA      PConc       Gd       TA
# 1131         0.0        Gd        TA      PConc       Gd       TA
# 1138       242.0        Ex        TA      PConc       Ex       TA
# 1170       734.0        Ex        TA      PConc       Ex       TA
# 1176       252.0        Gd        TA     CBlock       Ex       TA
# 1190         0.0        TA        TA     CBlock       Gd       TA
# 1193       206.0        Gd        TA      PConc       Ex       Gd
# 1247         0.0        TA        TA     CBlock       TA       TA
# 1252         0.0        Gd        TA      PConc       Gd       TA
# 1283         0.0        TA        TA     CBlock       TA       TA
# 1327         0.0        TA        TA      PConc       TA       TA
# 1407         0.0        TA        Fa     BrkTil       Fa       Fa
# 1434       473.0        Gd        TA      PConc       Ex       TA
# 1446         0.0        TA        TA      PConc       Gd       TA
# 1453         0.0        TA        TA     CBlock       TA       TA
#
#      BsmtExposure BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  \
# 5              No          Unf         0.0          Unf         0.0
# 46             Mn          GLQ      1137.0          Unf         0.0
# 71             No          BLQ       579.0          Unf         0.0
# 81             No          Rec       788.0          Unf         0.0
# 137            No          GLQ       343.0          Unf         0.0
# 186            No          ALQ       636.0          Unf         0.0
# 201            No          GLQ       986.0          Unf         0.0
# 274            No          ALQ       624.0          Unf         0.0
# 276            Gd          ALQ      1733.0          Rec        92.0
# 295            No          ALQ       734.0          Unf         0.0
# 360            No          Unf         0.0          Unf         0.0
# 391            No          BLQ       173.0          Unf         0.0
# 420            Av          GLQ      1234.0          Unf         0.0
# 422            No          Unf         0.0          Unf         0.0
# 454            Gd          GLQ      1476.0          Unf         0.0
# 483            Gd          GLQ        16.0          Unf         0.0
# 513            No          GLQ       856.0          Unf         0.0
# 547            No          GLQ       902.0          Unf         0.0
# 561            Av          ALQ       800.0          Unf         0.0
# 592            No          BLQ       528.0          Unf         0.0
# 613            No          BLQ       637.0          Unf         0.0
# 767            Gd          GLQ      1036.0          Unf         0.0
# 775            Av          GLQ      1011.0          Unf         0.0
# 779            No          GLQ       864.0          Unf         0.0
# 783            Av          GLQ       501.0          Unf         0.0
# 791            No          BLQ       838.0          Unf         0.0
# 817            No          ALQ       566.0          Unf         0.0
# 876            No          Unf         0.0          Unf         0.0
# 908            No          Unf         0.0          Unf         0.0
# 940            No          BLQ       150.0          ALQ       404.0
# 943            Av          GLQ       602.0          Unf         0.0
# 953            No          BLQ       408.0          Unf         0.0
# 984            No          LwQ       122.0          Rec       448.0
# 1008           No          Unf         0.0          Unf         0.0
# 1048           Mn          GLQ        20.0          Unf         0.0
# 1131           No          Unf         0.0          Unf         0.0
# 1138           Gd          Unf         0.0          Unf         0.0
# 1170           No          GLQ      1206.0          Unf         0.0
# 1176           Gd          GLQ      1005.0          Unf         0.0
# 1190           No          ALQ        70.0          Unf         0.0
# 1193           No          Unf         0.0          Unf         0.0
# 1247           No          Rec       712.0          Unf         0.0
# 1252           No          Unf         0.0          Unf         0.0
# 1283           Av          BLQ       914.0          Unf         0.0
# 1327           No          Unf         0.0          Unf         0.0
# 1407           No          Unf         0.0          Unf         0.0
# 1434           Gd          GLQ      1573.0          Unf         0.0
# 1446           Mn          Unf         0.0          Unf         0.0
# 1453           No          Unf         0.0          Unf         0.0
#
#       BsmtUnfSF  TotalBsmtSF Heating HeatingQC CentralAir Electrical  \
# 5         763.0        763.0    GasA        Gd          Y      SBrkr
# 46        143.0       1280.0    GasA        Ex          Y      SBrkr
# 71        357.0        936.0    GasA        TA          Y      SBrkr
# 81        200.0        988.0    GasA        Ex          Y      SBrkr
# 137        80.0        423.0    GasA        Ex          Y      SBrkr
# 186       540.0       1176.0    GasA        Fa          Y      SBrkr
# 201       379.0       1365.0    GasA        Ex          Y      SBrkr
# 274       288.0        912.0    GasA        Ex          Y      SBrkr
# 276       189.0       2014.0    GasA        Gd          Y      SBrkr
# 295       160.0        894.0    GasA        Gd          Y      SBrkr
# 360       972.0        972.0    GasA        Ex          Y      SBrkr
# 391       916.0       1089.0    GasW        TA          Y      SBrkr
# 420       335.0       1569.0    GasA        Ex          Y      SBrkr
# 422       840.0        840.0    GasA        Ex          Y      SBrkr
# 454       120.0       1596.0    GasA        Ex          Y      SBrkr
# 483      1152.0       1168.0    GasA        Ex          Y      SBrkr
# 513       292.0       1148.0    GasA        Ex          Y      SBrkr
# 547       316.0       1218.0    GasA        Ex          Y      SBrkr
# 561       630.0       1430.0    GasA        TA          Y      SBrkr
# 592       590.0       1118.0    GasA        Ex          Y      SBrkr
# 613       675.0       1312.0    GasA        Ex          Y      SBrkr
# 767       482.0       1518.0    GasA        Ex          Y      SBrkr
# 775       873.0       1884.0    GasA        Ex          Y      SBrkr
# 779       325.0       1189.0    GasA        Ex          Y      SBrkr
# 783        25.0        526.0    GasA        Gd          Y      SBrkr
# 791       749.0       1587.0    GasA        TA          Y      SBrkr
# 817       359.0        925.0    GasA        TA          Y      SBrkr
# 876      1369.0       1369.0    GasA        Ex          Y      SBrkr
# 908      1550.0       1550.0    GasA        Ex          Y      SBrkr
# 940       254.0        808.0    GasA        Ex          Y      SBrkr
# 943       191.0        793.0    GasA        Ex          Y      SBrkr
# 953       456.0        864.0    GasA        Gd          Y      SBrkr
# 984         0.0        570.0    GasA        Gd          N      SBrkr
# 1008      969.0        969.0    GasA        TA          N      FuseA
# 1048     1526.0       1546.0    GasA        Ex          Y      SBrkr
# 1131     1689.0       1689.0    GasA        Ex          Y      SBrkr
# 1138     1824.0       1824.0    GasA        Ex          Y      SBrkr
# 1170      644.0       1850.0    GasA        Ex          Y      SBrkr
# 1176       42.0       1047.0    GasA        TA          Y      SBrkr
# 1190      785.0        855.0    GasA        Gd          Y      SBrkr
# 1193     1721.0       1721.0    GasA        Ex          Y      SBrkr
# 1247      312.0       1024.0    GasA        TA          Y      SBrkr
# 1252     1143.0       1143.0    GasA        Ex          Y      SBrkr
# 1283      210.0       1124.0    GasA        Ex          Y      SBrkr
# 1327      798.0        798.0    GasA        Gd          Y      SBrkr
# 1407      832.0        832.0    GasA        TA          Y      FuseF
# 1434        0.0       1573.0    GasA        Ex          Y      SBrkr
# 1446      264.0        264.0    GasA        TA          Y      SBrkr
# 1453      546.0        546.0    GasA        TA          Y      SBrkr
#
#       1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  BsmtFullBath  BsmtHalfBath  \
# 5          763       892             0       1655           0.0           0.0
# 46        1280      1215             0       2495           1.0           0.0
# 71         936         0             0        936           1.0           0.0
# 81        1030       582             0       1612           0.0           0.0
# 137        896       756             0       1652           1.0           0.0
# 186       1193         0             0       1193           0.0           0.0
# 201       1365      1325             0       2690           1.0           0.0
# 274        912         0             0        912           1.0           0.0
# 276       2014         0             0       2014           1.0           0.0
# 295        894         0             0        894           1.0           0.0
# 360       1044         0           436       1480           0.0           0.0
# 391       1089         0             0       1089           1.0           0.0
# 420       1611         0             0       1611           1.0           0.0
# 422        840       885             0       1725           0.0           0.0
# 454       1648         0             0       1648           1.0           1.0
# 483       1168      1332             0       2500           0.0           0.0
# 513       1170      1162             0       2332           1.0           0.0
# 547       1218         0             0       1218           1.0           0.0
# 561       1430         0             0       1430           0.0           1.0
# 592       1118         0             0       1118           1.0           0.0
# 613       1312         0             0       1312           0.0           0.0
# 767       1537         0             0       1537           1.0           0.0
# 775       1728         0             0       1728           1.0           0.0
# 779       1189         0             0       1189           1.0           0.0
# 783        526       462             0        988           1.0           0.0
# 791       1587         0             0       1587           0.0           0.0
# 817       1422         0             0       1422           1.0           0.0
# 876       1369         0             0       1369           0.0           0.0
# 908       1550         0             0       1550           0.0           0.0
# 940        808         0             0        808           0.0           0.0
# 943       1280         0             0       1280           0.0           1.0
# 953       1154         0             0       1154           0.0           0.0
# 984        761       380             0       1141           0.0           0.0
# 1008       969       245             0       1214           0.0           0.0
# 1048      1546         0             0       1546           0.0           0.0
# 1131      1689         0             0       1689           0.0           0.0
# 1138      1824         0             0       1824           0.0           0.0
# 1170      1850       848             0       2698           1.0           0.0
# 1176      1083         0             0       1083           1.0           0.0
# 1190       855       601             0       1456           0.0           0.0
# 1193      1740         0             0       1740           0.0           0.0
# 1247      1024         0             0       1024           0.0           0.0
# 1252      1143         0             0       1143           0.0           0.0
# 1283      1124         0             0       1124           1.0           0.0
# 1327       840         0             0        840           0.0           0.0
# 1407       846       492             0       1338           0.0           0.0
# 1434      1778         0             0       1778           2.0           0.0
# 1446       616       688             0       1304           0.0           0.0
# 1453       546       546             0       1092           0.0           0.0
#
#       FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr KitchenQual  \
# 5            2         1             3             1          TA
# 46           2         1             4             1          Gd
# 71           1         0             2             1          TA
# 81           1         1             3             1          TA
# 137          2         1             3             1          Gd
# 186          2         0             3             1          TA
# 201          2         1             3             1          Ex
# 274          1         0             3             1          Gd
# 276          2         0             2             1          Gd
# 295          1         0             2             1          TA
# 360          1         0             3             1          TA
# 391          1         0             3             1          TA
# 420          2         0             3             1          Gd
# 422          2         1             3             1          Gd
# 454          2         0             2             1          Ex
# 483          3         1             5             1          Ex
# 513          2         1             4             1          Ex
# 547          2         0             2             1          Gd
# 561          2         0             3             1          TA
# 592          1         0             3             1          Gd
# 613          1         1             3             1          TA
# 767          2         0             3             1          Gd
# 775          2         0             3             1          Gd
# 779          2         0             2             1          TA
# 783          1         0             2             1          TA
# 791          2         0             3             1          TA
# 817          1         0             3             1          TA
# 876          2         0             3             1          Gd
# 908          2         1             2             1          Gd
# 940          1         0             2             1          TA
# 943          2         0             3             1          TA
# 953          1         1             3             1          Ex
# 984          1         0             3             1          TA
# 1008         1         0             2             1          TA
# 1048         2         0             3             1          Gd
# 1131         2         0             3             1          Gd
# 1138         2         0             3             1          Ex
# 1170         2         1             4             1          Ex
# 1176         1         0             2             1          TA
# 1190         2         1             3             1          TA
# 1193         2         0             4             1          Gd
# 1247         1         1             3             1          TA
# 1252         1         1             1             1          Gd
# 1283         1         0             3             1          TA
# 1327         1         0             2             1          Fa
# 1407         2         0             3             1          TA
# 1434         2         0             2             1          Ex
# 1446         1         1             3             1          TA
# 1453         1         1             3             1          TA
#
#       TotRmsAbvGrd Functional  Fireplaces FireplaceQu GarageType  GarageYrBlt  \
# 5                7        Typ           1          TA     Attchd       1993.0
# 46               9        Typ           1          TA     Attchd       1993.0
# 71               5        Typ           1          Gd        NaN          NaN
# 81               7        Typ           0         NaN     Detchd       1950.0
# 137              6        Typ           0         NaN    BuiltIn       1994.0
# 186              5        Typ           1          TA     Attchd       1975.0
# 201              8        Typ           1          Gd     Attchd       2009.0
# 274              6        Typ           0         NaN     Attchd       1963.0
# 276              6       Maj1           2          Gd     Attchd       1980.0
# 295              5        Typ           1          Po     Detchd       1988.0
# 360              6        Typ           0         NaN     Detchd       1920.0
# 391              5        Typ           1          Gd     Detchd       1954.0
# 420              6        Typ           0         NaN     Attchd       2002.0
# 422              6        Typ           0         NaN     Attchd       2002.0
# 454              5        Typ           1          Gd     Attchd       2007.0
# 483              9        Typ           1          Gd    BuiltIn       2005.0
# 513              9        Typ           1          Gd    BuiltIn       2004.0
# 547              6        Typ           0         NaN     Attchd       2008.0
# 561              6        Typ           2          TA     Attchd       1974.0
# 592              6        Typ           0         NaN     Attchd       1960.0
# 613              6        Typ           1          Gd     Attchd       1958.0
# 767              8        Typ           0         NaN     Attchd       2007.0
# 775              7        Typ           1          Gd     Attchd       2007.0
# 779              4        Typ           0         NaN     Attchd       1997.0
# 783              5        Typ           0         NaN    BuiltIn       1973.0
# 791              7        Typ           1          Gd     Attchd       1971.0
# 817              7       Min2           0         NaN     Detchd       1988.0
# 876              5        Typ           0         NaN     Attchd       2007.0
# 908              5        Typ           0         NaN     Attchd       2007.0
# 940              5        Typ           0         NaN     Detchd       1963.0
# 943              6        Typ           1          TA    Basment       1966.0
# 953              6        Typ           0         NaN     Detchd       1962.0
# 984              6        Typ           0         NaN     Detchd       1930.0
# 1008             6        Typ           0         NaN     Detchd       1920.0
# 1048             7        Typ           0         NaN     Attchd       2005.0
# 1131             7        Typ           0         NaN     Attchd       2007.0
# 1138             8        Typ           1          Gd     Attchd       2006.0
# 1170            11        Typ           1          Gd     Attchd       2006.0
# 1176             5        Typ           1          Fa     Attchd       1976.0
# 1190             6        Typ           1          TA     Attchd       1976.0
# 1193             8        Typ           0         NaN     Attchd       2006.0
# 1247             5        Typ           0         NaN     Attchd       1965.0
# 1252             5        Typ           1          Gd     Attchd       2004.0
# 1283             6        Typ           1          TA     Attchd       1956.0
# 1327             5        Typ           0         NaN     Detchd       1938.0
# 1407             7        Typ           0         NaN     Detchd       1974.0
# 1434             5        Typ           1          Gd     Attchd       2005.0
# 1446             5        Typ           1          TA    BuiltIn       1977.0
# 1453             5        Typ           0         NaN        NaN          NaN
#
#      GarageFinish  GarageCars  GarageArea GarageQual GarageCond PavedDrive  \
# 5             Fin         2.0       440.0         TA         TA          Y
# 46            Unf         2.0       660.0         TA         TA          Y
# 71            NaN         0.0         0.0        NaN        NaN          P
# 81            Unf         1.0       363.0         TA         TA          Y
# 137           RFn         2.0       473.0         TA         TA          Y
# 186           Unf         2.0       506.0         TA         TA          Y
# 201           RFn         3.0       864.0         TA         TA          Y
# 274           RFn         1.0       300.0         TA         TA          Y
# 276           RFn         3.0       864.0         TA         TA          Y
# 295           Unf         2.0       396.0         TA         TA          Y
# 360           Unf         1.0       207.0         Fa         TA          Y
# 391           RFn         1.0       252.0         TA         TA          P
# 420           RFn         3.0      1231.0         TA         TA          Y
# 422           RFn         2.0       550.0         TA         TA          Y
# 454           Fin         2.0       482.0         TA         TA          Y
# 483           Fin         3.0       683.0         TA         TA          Y
# 513           Fin         3.0       756.0         TA         TA          Y
# 547           Fin         2.0       462.0         TA         TA          Y
# 561           Unf         2.0       484.0         TA         TA          Y
# 592           RFn         1.0       264.0         TA         TA          Y
# 613           RFn         2.0       495.0         TA         TA          Y
# 767           Fin         3.0       788.0         TA         TA          Y
# 775           Fin         2.0       520.0         TA         TA          Y
# 779           RFn         2.0       392.0         TA         TA          Y
# 783           RFn         1.0       297.0         TA         TA          Y
# 791           Unf         2.0       525.0         TA         TA          Y
# 817           Unf         2.0       576.0         TA         TA          Y
# 876           Unf         2.0       605.0         TA         TA          Y
# 908           Fin         2.0       528.0         TA         TA          Y
# 940           Unf         1.0       308.0         TA         TA          N
# 943           Fin         2.0       432.0         TA         TA          Y
# 953           Unf         1.0       336.0         TA         TA          Y
# 984           Unf         1.0       252.0         Fa         Fa          Y
# 1008          Unf         1.0       216.0         TA         TA          N
# 1048          RFn         3.0       796.0         TA         TA          Y
# 1131          Fin         2.0       433.0         TA         TA          Y
# 1138          Fin         3.0       932.0         TA         TA          Y
# 1170          RFn         3.0       736.0         TA         TA          Y
# 1176          RFn         2.0       596.0         TA         TA          Y
# 1190          RFn         2.0       460.0         TA         TA          Y
# 1193          RFn         3.0       874.0         TA         TA          Y
# 1247          Unf         1.0       308.0         TA         TA          Y
# 1252          RFn         2.0       588.0         TA         TA          Y
# 1283          Fin         1.0       353.0         TA         TA          Y
# 1327          Unf         1.0       250.0         TA         Fa          N
# 1407          Unf         2.0       528.0         TA         TA          N
# 1434          Fin         2.0       495.0         TA         TA          Y
# 1446          RFn         1.0       336.0         TA         TA          Y
# 1453          NaN         0.0         0.0        NaN        NaN          Y
#
#       WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  \
# 5            157           84              0          0            0
# 46           224           32              0          0            0
# 71            51            0            135          0            0
# 81             0            0              0          0            0
# 137            0            0              0          0            0
# 186           40            0              0          0            0
# 201            0          197              0          0            0
# 274            0            0              0          0            0
# 276          462            0              0        255            0
# 295            0            0              0        360            0
# 360            0            0            176          0            0
# 391          328            0              0          0            0
# 420          262           93              0          0            0
# 422            0           48              0          0            0
# 454          162           53              0        153            0
# 483          192           32              0          0            0
# 513          224          142              0          0            0
# 547          168          168              0          0            0
# 561          117          108            165          0            0
# 592          290            0              0          0            0
# 613            0          304            144          0            0
# 767            0           26              0          0            0
# 775            0          276              0          0            0
# 779            0          122              0          0            0
# 783          120          101              0          0            0
# 791            0           44              0          0            0
# 817          252            0              0          0            0
# 876            0          203              0          0            0
# 908            0          102              0          0            0
# 940          143            0              0          0            0
# 943          140           40              0          0            0
# 953           63            0              0          0            0
# 984            0            0             96          0            0
# 1008           0            0             77          0            0
# 1048         144           42              0          0            0
# 1131         100           39              0          0            0
# 1138         160           36              0          0          108
# 1170         250            0              0          0            0
# 1176         444            0             40          0            0
# 1190           0           28              0          0            0
# 1193           0           43              0          0            0
# 1247           0            0              0          0            0
# 1252           0          191              0          0            0
# 1283           0          211            180          0          142
# 1327         112            0              0          0            0
# 1407           0            0            208          0            0
# 1434         123           53              0          0          153
# 1446         141            0              0          0            0
# 1453           0           34              0          0            0
#
#       PoolArea PoolQC  Fence MiscFeature  MiscVal  MoSold  YrSold SaleType  \
# 5            0    NaN    NaN         NaN        0       4    2010       WD
# 46           0    NaN    NaN         NaN        0       3    2010       WD
# 71           0    NaN  MnPrv         NaN        0       5    2010       WD
# 81           0    NaN  MnPrv         NaN        0       3    2010       WD
# 137          0    NaN    NaN         NaN        0       6    2010       WD
# 186          0    NaN    NaN         NaN        0       8    2009       WD
# 201          0    NaN    NaN         NaN        0       7    2009      New
# 274          0    NaN   GdWo         NaN        0      10    2009       WD
# 276          0    NaN  MnPrv         NaN        0       4    2009       WD
# 295          0    NaN   GdWo         NaN        0       8    2009       WD
# 360          0    NaN    NaN         NaN        0       9    2009    ConLI
# 391          0    NaN  MnPrv         NaN        0       9    2009       WD
# 420          0    NaN    NaN         NaN        0       9    2009       WD
# 422          0    NaN    NaN         NaN        0      11    2009       WD
# 454          0    NaN    NaN         NaN        0       6    2009      New
# 483          0    NaN    NaN         NaN        0       7    2008       WD
# 513          0    NaN    NaN         NaN        0       7    2008       WD
# 547          0    NaN    NaN         NaN        0       4    2008      New
# 561          0    NaN    NaN         NaN        0       7    2008       WD
# 592          0    NaN  MnPrv         NaN        0       8    2008       WD
# 613          0    NaN  MnPrv        Othr     6500       4    2008       WD
# 767          0    NaN    NaN         NaN        0       4    2008       WD
# 775          0    NaN    NaN         NaN        0       1    2008       WD
# 779          0    NaN    NaN         NaN        0       4    2008       WD
# 783          0    NaN    NaN         NaN        0       6    2008       WD
# 791          0    NaN    NaN         NaN        0       3    2007       WD
# 817          0    NaN   GdWo         NaN        0       9    2007       WD
# 876          0    NaN    NaN         NaN        0       9    2007      New
# 908          0    NaN    NaN         NaN        0       7    2007      New
# 940          0    NaN    NaN         NaN        0       7    2007      COD
# 943          0    NaN    NaN         NaN        0       6    2007       WD
# 953          0    NaN    NaN         NaN        0       7    2007       WD
# 984          0    NaN    NaN         NaN        0       5    2007    ConLw
# 1008         0    NaN  MnPrv         NaN        0       9    2007       WD
# 1048         0    NaN    NaN         NaN        0       6    2007       WD
# 1131         0    NaN    NaN         NaN        0       4    2007      New
# 1138         0    NaN    NaN         NaN        0       9    2007      New
# 1170         0    NaN    NaN         NaN        0       7    2006      New
# 1176         0    NaN    NaN         NaN        0       7    2006       WD
# 1190         0    NaN    NaN         NaN        0       7    2006       WD
# 1193         0    NaN    NaN         NaN        0       9    2006      New
# 1247         0    NaN  MnPrv         NaN        0       1    2006       WD
# 1252         0    NaN    NaN         NaN        0       5    2006       WD
# 1283         0    NaN    NaN         NaN        0       5    2006       WD
# 1327         0    NaN    NaN         NaN        0       6    2006       WD
# 1407         0    NaN  GdPrv         NaN        0       5    2006       WD
# 1434         0    NaN    NaN         NaN        0       2    2006      New
# 1446         0    NaN    NaN         NaN        0       5    2006       WD
# 1453         0    NaN  GdPrv         NaN        0       6    2006       WD
#
#      SaleCondition
# 5           Normal
# 46          Normal
# 71          Normal
# 81          Normal
# 137         Normal
# 186         Normal
# 201        Partial
# 274         Normal
# 276         Normal
# 295         Normal
# 360         Family
# 391         Normal
# 420         Normal
# 422         Normal
# 454        Partial
# 483         Normal
# 513         Normal
# 547        Partial
# 561         Normal
# 592         Normal
# 613         Normal
# 767         Normal
# 775         Normal
# 779         Normal
# 783         Normal
# 791         Normal
# 817         Normal
# 876        Partial
# 908        Partial
# 940         Normal
# 943         Normal
# 953         Normal
# 984         Normal
# 1008       AdjLand
# 1048        Normal
# 1131       Partial
# 1138       Partial
# 1170       Partial
# 1176        Normal
# 1190        Normal
# 1193       Partial
# 1247        Normal
# 1252        Normal
# 1283        Normal
# 1327        Normal
# 1407       AdjLand
# 1434       Partial
# 1446        Normal
# 1453        Normal

# %%
#Process NaNs in training and test data frames

#Deal with Garage NaNs in test record 1116 of the test set
garage_cols = [col for col in test.columns if 'Garage' in col]
garage_cols.remove('GarageType')
garage_groups = house_train.groupby(['MSZoning','GarageType'])[garage_cols].agg(lambda x: mode(x)[0])
garage_groups_1116 = garage_groups.loc['RM','Detchd']
    
def fill_row_na(df,row,fill_group):
    '''function to fill in missing values for a particular dataframe row using a groupby object created outside the function'''
    for ind, item in fill_group.iteritems():
        df.loc[row,ind] = item
    return df

house_test = fill_row_na(house_test,1116,garage_groups_1116)

#Correct GarageYrBlt = 2207 in test set
house_test.loc[1132,'GarageYrBlt'] = 2007

#Test set record 660 creates a specific problem as it records a NaN for TotalBsmtSF. Setting this to 0 will allow
#the na_processing function below to handle the other NaNs
house_test.loc[house_test['TotalBsmtSF'].isna(),'TotalBsmtSF'] = 0



df_tst = house_test.copy()
df_trn = house_train.copy()
df_train = house_train.copy()

na_col_trn = df_trn.isna().any()
trn_na = df_trn.loc[:,na_col_trn].isna().sum()

na_col_tst = df_tst.isna().any()
tst_na = df_tst.loc[:,na_col_tst].isna().sum()

display(pd.DataFrame([trn_na,tst_na],index=['train','test']).T)

def na_processing(df,df_train):
    lot_frontage_fill = df_train.groupby('Neighborhood').agg({'LotFrontage':'mean'})
    df = df.set_index('Neighborhood')
    df['LotFrontage'].fillna(lot_frontage_fill['LotFrontage'],inplace=True)
    df = df.reset_index()

    df['Electrical'].fillna(df_train['Electrical'].mode()[0],inplace=True)

    df['MSZoning'].fillna(df_train['MSZoning'].mode()[0],inplace=True)

    df['Utilities'].fillna(df_trn['Utilities'].mode()[0],inplace=True)

    df.loc[(df['BsmtQual'].isna()) & (df['TotalBsmtSF']>0),'BsmtQual'] = 'TA'
    
    df.loc[df['TotalBsmtSF']==0,['BsmtQual','BsmtCond','BsmtExposure','BsmtFinType1','BsmtFinType2']] = \
    df.loc[df['TotalBsmtSF']==0,['BsmtQual','BsmtCond','BsmtExposure','BsmtFinType1','BsmtFinType2']].fillna('None')

    df['Alley'].fillna('None',inplace=True)
    
    df['FireplaceQu'].fillna('None',inplace=True)
    
    garage_cols = [col for col in test.columns if 'Garage' in col]
    df.loc[:,garage_cols] = df.loc[:,garage_cols].fillna('None')
    
    df['Fence'].fillna('None',inplace=True)
    
    df['MiscFeature'].fillna('None',inplace=True)
    
    mas_veneer_fill = df_train.groupby('Neighborhood')['MasVnrType'].agg(lambda x: mode(x)[0])
    df = df.set_index('Neighborhood')
#     df['MasVnrType'].fillna(mas_veneer_fill,inplace=True)
#     df = df.reset_index()
    
#     df['MasVnrArea'].fillna(0,inplace=True)
#     df['MasVnrType'].fillna('None',inplace=True)
    
    return df

df_tst = na_processing(df_tst,df_train)
df_trn = na_processing(df_trn,df_train)


na_col_trn = df_trn.isna().any()
trn_na = df_trn.loc[:,na_col_trn].isna().sum()

na_col_tst = df_tst.isna().any()
tst_na = df_tst.loc[:,na_col_tst].isna().sum()

display(pd.DataFrame([trn_na,tst_na],index=['train','test']).T)
# Out:
#                train    test
# LotFrontage    259.0   227.0
# Alley         1369.0  1352.0
# MasVnrType       8.0    16.0
# MasVnrArea       8.0    15.0
# BsmtQual        37.0    44.0
# BsmtCond        37.0    45.0
# BsmtExposure    38.0    44.0
# BsmtFinType1    37.0    42.0
# BsmtFinType2    38.0    42.0
# Electrical       1.0     NaN
# FireplaceQu    690.0   730.0
# GarageType      81.0    76.0
# GarageYrBlt     81.0    77.0
# GarageFinish    81.0    77.0
# GarageQual      81.0    77.0
# GarageCond      81.0    77.0
# PoolQC        1453.0  1456.0
# Fence         1179.0  1169.0
# MiscFeature   1406.0  1408.0
# MSZoning         NaN     4.0
# Utilities        NaN     2.0
# Exterior1st      NaN     1.0
# Exterior2nd      NaN     1.0
# BsmtFinSF1       NaN     1.0
# BsmtFinSF2       NaN     1.0
# BsmtUnfSF        NaN     1.0
# BsmtFullBath     NaN     2.0
# BsmtHalfBath     NaN     2.0
# KitchenQual      NaN     1.0
# Functional       NaN     2.0
# SaleType         NaN     1.0
#                train    test
# MasVnrType       8.0    16.0
# MasVnrArea       8.0    15.0
# BsmtExposure     1.0     2.0
# BsmtFinType2     1.0     NaN
# PoolQC        1453.0  1456.0
# Exterior1st      NaN     1.0
# Exterior2nd      NaN     1.0
# BsmtCond         NaN     3.0
# BsmtFinSF1       NaN     1.0
# BsmtFinSF2       NaN     1.0
# BsmtUnfSF        NaN     1.0
# BsmtFullBath     NaN     2.0
# BsmtHalfBath     NaN     2.0
# KitchenQual      NaN     1.0
# Functional       NaN     2.0
# SaleType         NaN     1.0

# %%
#Inspect numerical columns for correlation to sale price and shape of data
# correlation = house_train.corr()['SalePrice']
# kurt = house_train.kurtosis()
# skew = house_train.skew()
# cols = ['Price_Correlation','Kurtosis','Skewness']

# house_numerical = pd.concat([correlation,kurt,skew],axis=1)
# house_numerical.columns = cols
# display(house_numerical.sort_values(['Price_Correlation'],ascending=False))

# %%
# fig, ax = plt.subplots(1,3,figsize=(20,8))
# house_train.hist(column='SalePrice',bins=20,ax=ax[0])

# display(kstest(house_train['SalePrice'],'norm'))
# display('Sale Price Skew = {:.2f}'.format(house_train['SalePrice'].skew()))
# display('Sale Price Kurtosis = {:.2f}'.format(house_train['SalePrice'].kurtosis()))

# sales_price_log = np.log(house_train['SalePrice'])
# ax[1].hist(sales_price_log,bins=20,color='red')
# ax[1].set_title('Log_SalePrice')
# display('Log Skew = {:.2f}'.format(sales_price_log.skew()))
# display('Log Kurtosis = {:.2f}'.format(sales_price_log.kurtosis()))

# sns.boxplot(y='SalePrice',data=house_train,ax=ax[2])

# %% [markdown]
# The Sale Price target is normally distributed though in its base form is right-tail skewed. Taking the log of Sale Price corrects this so it may help the model to predict log Sale Price and then take the exponential to create the final predictions.
#
# There are two clear outliers which should probably be removed from the training set before modelling.

# %%
# house_train['Log_SalePrice'] = np.log(house_train['SalePrice'])
# correlation_two = house_train.corr()['Log_SalePrice']
# log_house_numerical = house_numerical.join(correlation_two)
# log_house_numerical.rename(columns={'Log_SalePrice':'Log_Price_Corr'},inplace=True)
# log_house_numerical = log_house_numerical[['Price_Correlation','Log_Price_Corr','Kurtosis','Skewness']].sort_values('Log_Price_Corr',ascending=False)
# display(log_house_numerical.head(10))

# %% [markdown]
# Taking the log of the Sale Price improves the correlation factor of most nuerical variables, including nine of the top 10, without changing their order. This implies that using the log of the Sale Price may improve model accuracy, particularly in simpler models. I will continue to do base EDA using the Sale Price as this is the real-world value but may use its log in model buidling.

# %%
#Delete some extraneous variables created so far
# del[house_numerical,correlation,correlation_two]

# %%
#Examine Overall Quality and Condition
# fig, ax = plt.subplots(1,3,figsize=(20,8))
# sns.boxplot(x='OverallQual',y='SalePrice',data=house_train,ax=ax[0])
# sns.boxplot(x='OverallCond',y='SalePrice',data=house_train,ax=ax[1])
# sns.scatterplot(x='OverallQual',y='OverallCond',data=house_train,ax=ax[2])

# QualCon = log_house_numerical.loc[['OverallQual','OverallCond']]
# display(QualCon)

# Qual_var = house_train.groupby('OverallQual').agg({'SalePrice':'var'}).rename(columns={'SalePrice':'var_SalePrice'})
# display(Qual_var.T)

# display('Levene test of OverallQual and Sale Price = {}'.format(levene(house_train['OverallQual'],house_train['SalePrice'])))
# display('Levene test of OverallQual and Log Sale Price = {}'.format(levene(house_train['OverallQual'],house_train['Log_SalePrice'])))

# %%
# house_train['Box_OverallQual'] = boxcox(house_train['OverallQual'])[0]
# display(house_train[['Box_OverallQual','OverallQual','Log_SalePrice']].corr()['Log_SalePrice'])
# display('Levene test on Box-Cox transformer OverallQual = {}'.format(levene(house_train['Box_OverallQual'], \
#                             house_train['Log_SalePrice'])))
